# %% [markdown]
# # Classifiez automatiquement des biens de consommation

# %%
from IPython.display import display, HTML
display(HTML("<div style='text-align: center;'><img src='logo.png' alt='Logo' width='400'></div>"))
# Out:
# <div style='text-align: center;'><img src='logo.png' alt='Logo' width='400'></div>

# %%
import pandas as pd
import requests
import csv
from pprint import pprint
from IPython.display import display, Image

# %% [markdown]
# ## Missions
# - Dans ce notebook, nous nous concentrerons sur la réalisation du test de collecte de produit à base de champagne via l'API :
#
# "Nous souhaitons élargir notre gamme de produits, en particulier dans l’épicerie fine. Pourrais-tu tester la collecte de produits à base de **“champagne”** via l’API disponible ici ? Je souhaiterais que tu puisses nous fournir une extraction des 10 premiers produits dans un fichier **“.csv”**, contenant pour chaque produit les données suivantes : **foodId**, **label**, **category**, **foodContentsLabel**, **imag"**.
#
# Stratégie : Code python
# API = https://rapidapi.com/edamam/api/edamam-food-and-grocery-database
# On obtient les données de l'API en cherchant spécifiquement le champagne comme ingrédient en s'inspirant du **'Code Snippets'** python fourni sur le site.

# %%
url = "https://edamam-food-and-grocery-database.p.rapidapi.com/api/food-database/v2/parser"

#Filtrer l'ingrédient champagne 
querystring = {"ingr": "champagne"}

headers = {
    "X-RapidAPI-Key": "3bbff61965msh1c7c69097fe7bf8p143182jsn5fe6caec4f33",
	"X-RapidAPI-Host": "edamam-food-and-grocery-database.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
data = response.json()

# %% [markdown]
# - On récupère les champs nécessaires, à savoir : foodId, label, category, foodContentsLabel, imag

# %%
filtered_data = []

if "hints" in data:
    for item in data["hints"]:
        food_data = item.get('food', {})
        relevant_info = {
            'foodId': food_data.get('foodId'),
            'label': food_data.get('label'),
            'category': food_data.get('category'),
            'foodContentsLabel': food_data.get('foodContentsLabel'),
            'image': food_data.get('image')
        }
        filtered_data.append(relevant_info)

# %% [markdown]
# - On récupère les 10 premiers produits

# %%
with open('champagne_data.csv', 'w', newline='') as csvfile:
    fieldnames = ["foodId", "label", "category", "foodContentsLabel", "image"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    # Prendre seulement les 10 premiers éléments de la liste
    for row in filtered_data[:10]:
        writer.writerow(row)

# %% [markdown]
# - On vérifie le résultat final

# %%
df = pd.read_csv('champagne_data.csv', sep = ",")
df
# Out:
#                               foodId                                   label  \
# 0  food_a656mk2a5dmqb2adiamu6beihduu                               Champagne
# 1  food_b8d1c2rbdpdok6bjpwmtlbsa5hs4        Champagne Vinaigrette, Champagne
# 2  food_axmullnbxsm8f5aug13l2aqoyu6j        Champagne Vinaigrette, Champagne
# 3  food_a7j75b0bk4sd87a34ed3tats8n31           Champagne Dressing, Champagne
# 4  food_b2xjyr5beqff2mbwycgjza8o1hxk        Champagne Vinaigrette, Champagne
# 5  food_a2z6lg7a3qtqbbbsw4yxgbx8ql4q           Champagne Dressing, Champagne
# 6  food_a7d4hjabk0x5sqby8om6gbf5c4tr           Champagne Truffles, Champagne
# 7  food_alpl44taoyv11ra0lic1qa8xculi                   Champagne Buttercream
# 8  food_agum7rba8gepbgajiid4zbgmcwad  Champagne Punch Concentrate, Champagne
# 9  food_arebcyiaufsqpnax8zj38bipaerf       Champagne Cotton Candy, Champagne
#
#          category                                  foodContentsLabel  \
# 0   Generic foods                                                NaN
# 1  Packaged foods  OLIVE OIL; BALSAMIC VINEGAR; CHAMPAGNE VINEGAR...
# 2  Packaged foods  INGREDIENTS: WATER; CANOLA OIL; CHAMPAGNE VINE...
# 3  Packaged foods  OLIVE OIL; BALSAMIC VINEGAR; CHAMPAGNE VINEGAR...
# 4  Packaged foods  CANOLA AND SOYBEAN OIL; WHITE WINE (CONTAINS S...
# 5  Packaged foods  SOYBEAN OIL; WHITE WINE (PRESERVED WITH SULFIT...
# 6  Packaged foods  NON-GMO MILK CHOCOLATE (CANE SUGAR; FULL CREAM...
# 7   Generic meals  sugar; butter; shortening; vanilla; champagne;...
# 8  Packaged foods  HIGH FRUCTOSE CORN SYRUP; WATER; LESS THAN 2%:...
# 9  Packaged foods                SUGAR; ARTIFICIAL & NATURAL FLAVOR.
#
#                                                image
# 0  https://www.edamam.com/food-img/a71/a718cf3c52...
# 1                                                NaN
# 2  https://www.edamam.com/food-img/d88/d88b64d973...
# 3                                                NaN
# 4                                                NaN
# 5  https://www.edamam.com/food-img/ab2/ab2459fc2a...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
# Affichage des 10 premiers produits
df.head(10)

# Vérifier les valeurs manquantes
print("\nValeurs manquantes par colonne :")
display(df.isnull().sum())

# Taux de valeurs manquantes
print("\nTaux de valeurs manquantes :")
display(df.isnull().mean() * 100)

# Types de produits (catégories) présents
print("\nRépartition des catégories de produits :")
display(df['category'].value_counts())

# Affichage des produits sans image (optionnel)
print("\nProduits sans image :")
display(df[df['image'].isnull()])
# Out:
# Valeurs manquantes par colonne :
# foodId               0
# label                0
# category             0
# foodContentsLabel    1
# image                7
# dtype: int64
# Taux de valeurs manquantes :
# foodId                0.0
# label                 0.0
# category              0.0
# foodContentsLabel    10.0
# image                70.0
# dtype: float64
# Répartition des catégories de produits :
# category
# Packaged foods    8
# Generic foods     1
# Generic meals     1
# Name: count, dtype: int64
# Produits sans image :
#                               foodId                                   label  \
# 1  food_b8d1c2rbdpdok6bjpwmtlbsa5hs4        Champagne Vinaigrette, Champagne
# 3  food_a7j75b0bk4sd87a34ed3tats8n31           Champagne Dressing, Champagne
# 4  food_b2xjyr5beqff2mbwycgjza8o1hxk        Champagne Vinaigrette, Champagne
# 6  food_a7d4hjabk0x5sqby8om6gbf5c4tr           Champagne Truffles, Champagne
# 7  food_alpl44taoyv11ra0lic1qa8xculi                   Champagne Buttercream
# 8  food_agum7rba8gepbgajiid4zbgmcwad  Champagne Punch Concentrate, Champagne
# 9  food_arebcyiaufsqpnax8zj38bipaerf       Champagne Cotton Candy, Champagne
#
#          category                                  foodContentsLabel image
# 1  Packaged foods  OLIVE OIL; BALSAMIC VINEGAR; CHAMPAGNE VINEGAR...   NaN
# 3  Packaged foods  OLIVE OIL; BALSAMIC VINEGAR; CHAMPAGNE VINEGAR...   NaN
# 4  Packaged foods  CANOLA AND SOYBEAN OIL; WHITE WINE (CONTAINS S...   NaN
# 6  Packaged foods  NON-GMO MILK CHOCOLATE (CANE SUGAR; FULL CREAM...   NaN
# 7   Generic meals  sugar; butter; shortening; vanilla; champagne;...   NaN
# 8  Packaged foods  HIGH FRUCTOSE CORN SYRUP; WATER; LESS THAN 2%:...   NaN
# 9  Packaged foods                SUGAR; ARTIFICIAL & NATURAL FLAVOR.   NaN

# %%
# Récupérer les 3 premières URLs d'images non nulles
urls = df['image'].dropna().head(3).tolist()

# Construire une chaîne HTML avec les images alignées sur la même ligne
html = '<div style="display: flex; gap: 10px;">'
for url in urls:
    html += f'<img src="{url}" style="height:150px;">'
html += '</div>'

display(HTML(html))
# Out:
# <div style="display: flex; gap: 10px;"><img src="https://www.edamam.com/food-img/a71/a718cf3c52add522128929f1f324d2ab.jpg" style="height:150px;"><img src="https://www.edamam.com/food-img/d88/d88b64d97349ed062368972113124e35.jpg" style="height:150px;"><img src="https://www.edamam.com/food-img/ab2/ab2459fc2a98cd35f68b848be2337ecb.jpg" style="height:150px;"></div>

# %% [markdown]
# ### 🎯 Objectif
#
# L’objectif était de tester la faisabilité d’une extraction de produits à base de **“champagne”** via l’API Edamam.
#
# ### ✅ Résultat
#
# Nous avons extrait les 10 premiers produits retournés par l’API contenant **"champagne"** comme ingrédient. Les informations suivantes ont été récupérées pour chaque produit :
# - foodId
# - label
# - category
# - foodContentsLabel
# - image
#
# Ces données ont été enregistrées dans un fichier CSV nommé **`champagne_data.csv`**.
#
# ### 🔍 Observations
#
# - Les produits incluent des vinaigrettes, truffes, bonbons, etc.
# - Certaines entrées ne contiennent pas d’image (`image = NaN`).
# - L’API fournit rapidement des résultats exploitables.
#
# ### 💡 Suggestions
#
# - Ajouter un contrôle d’erreurs pour sécuriser les appels à l’API.
# - Supprimer les doublons éventuels (produits très similaires).
